# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col="Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col="Column")

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = df['Country'] == 'India'
india_df = df.loc[filt]

# %%
india_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
india_df.to_csv('data/india.csv')

# %%
india_df = india_df.dropna(axis='index', how='any')

# %%
india_df.shape
# Out:
# (246, 84)

# %%
india_df.to_csv('data/india.csv')

# %%
india_df.to_excel('data/modified_india.xlsx')

# %%
test = pd.read_excel('data/modified_india.xlsx', index_col='Respondent')

# %%
test
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 83          I am a developer by profession      Yes
# 104         I am a developer by profession      Yes
# 1181        I am a developer by profession      Yes
# 1584        I am a developer by profession      Yes
# 1824        I am a developer by profession      Yes
# ...                                    ...      ...
# 86596       I am a developer by profession       No
# 86764       I am a developer by profession       No
# 87353       I am a developer by profession      Yes
# 87385       I am a developer by profession      Yes
# 87531       I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 83          Less than once a month but more than once per ...
# 104                                                     Never
# 1181        Less than once a month but more than once per ...
# ...

# %%
india_df.to_json('data/json_india.json')

# %%
india_df.to_json('data/json_india.json', orient='records', lines=True)

# %%
test = pd.read_json('data/json_india.json', orient='records', lines=True)

# %%
test.head()
# Out:
#                        MainBranch Hobbyist  \
# 0  I am a developer by profession      Yes
# 1  I am a developer by profession      Yes
# 2  I am a developer by profession      Yes
# 3  I am a developer by profession      Yes
# 4  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0  Less than once a month but more than once per ...
# 1                                              Never
# 2  Less than once a month but more than once per ...
# 3                            Less than once per year
# 4                         Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 1  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# ...
