# %% [markdown]
# # Pie Charts

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.style.use('fivethirtyeight')

# %%
slices = [60, 40]
plt.pie(slices)
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
slices = [60, 40]
labels = ['sixty', 'forty']
plt.pie(slices, labels=labels)
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
slices = [120, 80]
labels = ['sixty', 'forty']
plt.pie(slices, labels=labels)
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
slices = [120, 80]
labels = ['sixty', 'forty']
plt.pie(slices, labels=labels,wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
slices = [120, 80, 30, 20]
labels = ['sixty', 'forty', 'extra1', 'extra2']
colors = ['blue', 'red', 'yellow', 'green']

plt.pie(slices, labels=labels,colors=colors, wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
slices = [120, 80, 30, 20]
labels = ['sixty', 'forty', 'extra1', 'extra2']
colors = [
'#008fd5',
'#fc4f30',
'#e5ae37',
'#6d904f']

plt.pie(slices, labels=labels,colors=colors, wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
slices = [59219, 55466, 47544, 36443, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly']
plt.pie(slices, labels=labels,wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
plt.pie(slices, labels=labels,wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
explode = [0, 0, 0, 0.1, 0]

plt.pie(slices, labels=labels,explode=explode, wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
plt.pie(slices, labels=labels,explode=explode, shadow=True, wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
plt.pie(slices, labels=labels,startangle=90,explode=explode, shadow=True, wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')

# %%
plt.pie(slices, labels=labels,startangle=90,explode=explode,
        autopct='%1.1f%%',shadow=True, wedgeprops={'edgecolor':'black'})
plt.title('My Awesome Pie Chart')
# Out:
# Text(0.5, 1.0, 'My Awesome Pie Chart')
